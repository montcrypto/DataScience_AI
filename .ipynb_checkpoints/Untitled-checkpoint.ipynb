# %%
>>> prefecture=['滋賀','京都','大阪','兵庫','奈良','和歌山']
>>> city=['大津市','京都市','大阪市','神戸市','奈良市','和歌山市']
>>> tree=['モミジ','北山スギ','イチョウ','クスノキ','スギ','ウバメガシ']
>>> flower=[]

>>> for i,p in enumerate(zip(prefecture,city,tree)):
...     print(str(i+1)+'番'+' 都道府県名 '+p[0]+' 県庁所在地 '+p[1]+' 県の木 '+p[2])
# Out:
# 1番 都道府県名 滋賀 県庁所在地 大津市 県の木 モミジ
# 2番 都道府県名 京都 県庁所在地 京都市 県の木 北山スギ
# 3番 都道府県名 大阪 県庁所在地 大阪市 県の木 イチョウ
# 4番 都道府県名 兵庫 県庁所在地 神戸市 県の木 クスノキ
# 5番 都道府県名 奈良 県庁所在地 奈良市 県の木 スギ
# 6番 都道府県名 和歌山 県庁所在地 和歌山市 県の木 ウバメガシ

# %%
import numpy as np
x= np.arange(-3,3,0.1)
y=x**3

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(x,y,label="y=x^3")
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
fig, axes = plt.subplots(ncols=3,nrows=2, figsize=(12,8))
power=[1/3,1/2,1,2,3,5]
for i,p in enumerate(power):
    c,r=divmod(i,3)
    axes[c,r].plot(x,x**i,label="power of"+str(power[i]) )
    axes[c,r].legend()
    axes[c,r].set_xlabel('x')
    axes[c,r].set_ylabel('y')
plt.show()

# %%
>>> fig, axes = plt.subplots(ncols=3,nrows=2, figsize=(12,8))
>>> power=[1/3,1/2,1,2,3,5]
>>> for i,p in enumerate(power):
...     c,r=divmod(i,3)
...     axes[c,r].plot(x,x**i,label="power of"+str(power[i]) )
...     axes[c,r].legend()
...     axes[c,r].set_xlabel('x')
...     axes[c,r].set_ylabel('y')
>>> plt.show()

# %%
>>> univ_dic={'Kyoto University':(35.026244,135.780822),'Kyoto University of Education':(34.950215,135.773187),'Kyoto Institute of Technology':(35.049664,135.782046)}
print('京都教育大学の場所は',univ_dic['Kyoto University of Education'])
>>> import pandas as pd
>>> df=pd.DataFrame(univ_dic, index=('latitude','longitude'))
>>> dfn=df.T
>>> dfn['address']=['京都府京都市左京区吉田本町','京都府京都市伏見区深草藤森町1','京都府京都市左京区松ヶ崎橋上町1']
>>> dfn['students']=['12,958','1,332','2,656']
>>> dfn['teachers']=['3,441','110','281']
# Out:
# 京都教育大学の場所は (34.950215, 135.773187)

# %%
dfn
# Out:
#                                 latitude   longitude           address  \
# Kyoto University               35.026244  135.780822     京都府京都市左京区吉田本町
# Kyoto University of Education  34.950215  135.773187   京都府京都市伏見区深草藤森町1
# Kyoto Institute of Technology  35.049664  135.782046  京都府京都市左京区松ヶ崎橋上町1
#
#                               students teachers
# Kyoto University                12,958    3,441
# Kyoto University of Education    1,332      110
# Kyoto Institute of Technology    2,656      281

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(dfn['latitude'],dfn['longitude'], s=500, label=list(np.array((dfn.index))))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ee000f0d9d72> in <module>
#       2 import numpy as np
#       3
# ----> 4 plt.scatter(dfn['latitude'],dfn['longitude'], s=500, labels=list(np.array((dfn.index))))
#       5 plt.legend()
#       6 plt.show()
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4496                 )
#    4497         collection.set_transform(mtransforms.IdentityTransform())
# -> 4498         collection.update(kwargs)
#    4499
#    4500         if colors is None:
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'PathCollection' object has no property 'labels'

# %%
list(np.array((dfn.index)))
# Out:
# ['Kyoto University',
#  'Kyoto University of Education',
#  'Kyoto Institute of Technology']

# %%
import numpy as np
mat=np.random.rand(6,5)
mat
# Out:
# array([[0.5043002 , 0.37382591, 0.01861786, 0.77352815, 0.72587279],
#        [0.67650871, 0.77427006, 0.7668957 , 0.06823305, 0.43429725],
#        [0.26136469, 0.12931472, 0.70292283, 0.68489985, 0.54586013],
#        [0.54013191, 0.07269366, 0.61483121, 0.81358582, 0.30430211],
#        [0.25950663, 0.77727233, 0.96121003, 0.55419164, 0.03502402],
#        [0.7634411 , 0.22957565, 0.47430193, 0.53136687, 0.04776636]])

# %%
mat[1:3,2:4]
# Out:
# array([[0.13504302, 0.54144137],
#        [0.08206899, 0.54896378]])

# %%
mat[1:3,2:4]=0
mat
# Out:
# array([[0.93987159, 0.755175  , 0.25051673, 0.91663363, 0.6494    ],
#        [0.50657243, 0.17434289, 0.        , 0.        , 0.22875137],
#        [0.09517721, 0.43037945, 0.        , 0.        , 0.33087475],
#        [0.17262683, 0.51725863, 0.83124545, 0.70180956, 0.35399325],
#        [0.30247671, 0.52517184, 0.92602194, 0.01585037, 0.26942446]])

# %%
mat.max(),mat.min(),mat.var(),mat.std(),mat.mean(),mat.argmax(),mat.argmin()
# Out:
# (0.939871591660584,
#  0.0,
#  0.0963984685876449,
#  0.31048102774186526,
#  0.3957429631622778,
#  0,
#  7)

# %%
mat.sum(axis=1)
# Out:
# array([3.51159695, 0.90966669, 0.85643142, 2.57693371, 2.03894532])
