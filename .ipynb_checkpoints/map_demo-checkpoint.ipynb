# %% [markdown]
# ### 京都の３つの国立大学の座標を辞書形式のデータに収納する。緯度と経度の情報を元に位置関係をプロットする。

# %%
univ_dic={'Kyoto University':(35.026244,135.780822),'Kyoto University of Education':(34.950215,135.773187),'Kyoto Institute of Technology':(35.049664,135.782046)}
print(univ_dic['Kyoto University of Education'])

import pandas as pd
df=pd.DataFrame(univ_dic, index=['latitude','longitude'])
df=df.T
display(df)

import matplotlib.pyplot as plt
df.plot(y='latitude',x='longitude', kind='scatter', grid=True, legend=True)
plt.xlim(135.70,135.90)
plt.ylim(34.90,35.10)
#plt.axis('square')
plt.show()
# Out:
# (34.950215, 135.773187)
#                                 latitude   longitude
# Kyoto University               35.026244  135.780822
# Kyoto University of Education  34.950215  135.773187
# Kyoto Institute of Technology  35.049664  135.782046

# %% [markdown]
# ### 文化庁のホームページから指定文化財のデータベースをダウンロードしてグラフ上に表示する。
# - 例として京都府の建造物指定文化財：Kyoto_Architecture.csv：
# - 日本地図はhttps://github.com/dataofjapan/land からJSONファイルを取得。

# %%
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

df_temple = pd.read_csv('../../GitHubData/DataScience_AI/data/GIS/Kyoto_Architecture.csv',usecols = [2, 5, 8, 16, 17],\
                        dtype  = {'名称': str, '種別1': str, '時代': str, '緯度': float, '経度': float})
df_temple = df_temple.rename(columns = {'名称': 'article', '種別1': 'category',\
                                        '時代': 'period', '緯度': 'latitude','経度': 'longitude'})

df_temple.plot(figsize=(6,6),y='latitude',x='longitude', kind='scatter', grid=True, legend=True)
plt.axis('square')
plt.show()

# %% [markdown]
# ### 地図上に文化財所在地をプロットする

# %% [markdown]
# - 日本地図府県境界データをgeopandasに読み込み、京都府のみを描画する。
# - そこに、文化財のデータを重ねて表示する。その際に国宝指定を赤、重要文化財指定を灰色とする。

# %%
import geopandas as gpd
df_jap = gpd.read_file('../../GitHubData/DataScience_AI/data/GIS/japan.geojson')

# 指定物件で色分け
colors=[]
for cat in df_temple.category:
    if cat == '国宝':
        colors.append('red')
    else:
        colors.append('gray')
            
fig, ax = plt.subplots(nrows=1,ncols=2,figsize = (16,16)) 
for i in range(2):
    if i == 1:
        ax[i].set_xlim([135.6,135.9]);ax[i].set_ylim([34.8,35.1])
    df_jap[df_jap['nam_ja'] == '京都府'].plot(ax=ax[i],figsize=(8,8), edgecolor='#444', facecolor='white', linewidth = 0.5)
    ax[i].scatter(df_temple.longitude,df_temple.latitude,color=colors)
plt.show()

# %% [markdown]
# ## 都道府県の地図を描く
# - 「e-stat 統計で見る日本」より、国税調査、小区分、境界データを47都道府県分ダウンロードして、その内Shapeファイルをgeopandaで読み込んで作図する。

# %%
import glob
data_dir='../../GitHubData/DataScience_AI/data/GIS/e-Stat_Kokuzei_Shp' # e-stat 統計で見る日本　国税調査　小区分　境界データ　Shape ファイル　
prefecture_shp=sorted(glob.glob(data_dir+'/*/*.shp'))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas as gpd

pref_name='宮崎県'
pref_id=df_jap.id[df_jap['nam_ja']=='宮崎県'].values
map_id=pref_id[0]-1

fig, ax = plt.subplots(figsize = (16,16)) 
gdf = gpd.read_file(prefecture_shp[map_id])      #gdf file に変換した。
gdf.plot(ax=ax, facecolor='white', edgecolor='black', linewidth=0.2)
ax.set_axis_off()
plt.show()

# %%
gdf
# Out:
#          KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME             S_NAME  \
# 0     45201001001   45  201  001001       宮崎県       宮崎市             橘通西１丁目
# 1     45201001002   45  201  001002       宮崎県       宮崎市             橘通西２丁目
# 2     45201001003   45  201  001003       宮崎県       宮崎市             橘通西３丁目
# 3     45201001004   45  201  001004       宮崎県       宮崎市             橘通西４丁目
# 4     45201001005   45  201  001005       宮崎県       宮崎市             橘通西５丁目
# ...           ...  ...  ...     ...       ...       ...                ...
# 2595  45443003004   45  443  003004       宮崎県      五ヶ瀬町      大字桑野内横通、黒板、下赤
# 2596  45443003005   45  443  003005       宮崎県      五ヶ瀬町    大字桑野内北の迫、興地、小半田
# 2597  45443003006   45  443  003006       宮崎県      五ヶ瀬町      大字桑野内土生、波帰、下山
# 2598  45443003007   45  443  003007       宮崎県      五ヶ瀬町  大字桑野内麦の崎、柿の尾栗の谷鳥越
# 2599  45443003008   45  443  003008       宮崎県      五ヶ瀬町            大字桑野内上赤
#
#      KIGO_E  HCODE         AREA  ...  N_CITY  KIGO_I               MOJI KBSUM  \
# 0      None   8101    82343.209  ...    None    None             橘通西１丁目     6
# 1      None   8101    38516.798  ...    None    None             橘通西２丁目     8
# 2      None   8101    46482.142  ...    None    None             橘通西３丁目    10
# 3      None   8101    45307.079  ...    None    None             橘通西４丁目     6
# 4      None   8101    67298.748  ...    None    None             橘通西５丁目     8
# ...     ...    ...          ...  ...     ...     ...                ...   ...
# 2595   None   8101  2201034.090  ...    None    None      大字桑野内横通、黒板、下赤     1
# 2596   None   8101  1961601.697  ...    None    None    大字桑野内北の迫、興地、小半田     1
# 2597   None   8101  2761722.980  ...    None    None      大字桑野内土生、波帰、下山     1
# 2598   None   8101  5411482.535  ...    None    None  大字桑野内麦の崎、柿の尾栗の谷鳥越     1
# 2599   None   8101  3061101.315  ...    None    None            大字桑野内上赤     1
#
#      JINKO SETAI     X_CODE    Y_CODE   KCODE1  \
# 0      285   168  131.42052  31.90802  0010-01
# 1      222   161  131.42174  31.91168  0010-02
# 2       14     7  131.42232  31.91487  0010-03
# 3       43    24  131.42294  31.91841  0010-04
# 4      559   328  131.42394  31.92226  0010-05
# ...    ...   ...        ...       ...      ...
# 2595    96    29  131.20811  32.72146  0030-04
# 2596    91    26  131.22201  32.72731  0030-05
# 2597    42    17  131.23053  32.73414  0030-06
# 2598    63    29  131.24078  32.72134  0030-07
# 2599    18     5  131.21857  32.71196  0030-08
#
#                                                geometry
# 0     POLYGON ((131.42159 31.90842, 131.42151 31.908...
# 1     POLYGON ((131.42217 31.91079, 131.42217 31.910...
# 2     POLYGON ((131.42269 31.91355, 131.42260 31.913...
# 3     POLYGON ((131.42345 31.91780, 131.42337 31.917...
# 4     POLYGON ((131.42432 31.92123, 131.42430 31.921...
# ...                                                 ...
# 2595  POLYGON ((131.20313 32.72898, 131.20407 32.729...
# 2596  POLYGON ((131.21781 32.73309, 131.21801 32.733...
# 2597  POLYGON ((131.22475 32.73933, 131.22495 32.739...
# 2598  POLYGON ((131.25234 32.73776, 131.25222 32.737...
# 2599  POLYGON ((131.22810 32.72359, 131.22800 32.723...
#
# [2600 rows x 36 columns]

# %% [markdown]
# ### 階級区分図（かいきゅうくぶんず、choropleth map）を人口密度と家族構成で作成する

# %%
gdf['DENSITY']= gdf['JINKO']/gdf['AREA']*10**6 # 1平方キロメートルあたりの人口
gdf['FAMILY']= gdf['JINKO']/gdf['SETAI']# 1世帯あたりの人数#print(gdf.head())
 
fig, ax = plt.subplots(ncols=2,figsize = (16,16))
for i, title in enumerate(['DENSITY','FAMILY']):
    gdf.plot(column = title, edgecolor = "black",scheme='quantiles', \
             linewidth=0.2, cmap='YlOrRd', ax=ax[i], legend = True)
    ax[i].set_axis_off()
plt.show()

# %%
gdf['FAMILY']= gdf['JINKO']/gdf['SETAI']# 1世帯あたりの人数
#print(gdf.info())
#print(gdf.head())
 
fig, ax = plt.subplots(figsize = (24,16))
gdf.plot(column = 'FAMILY', edgecolor = "black",scheme='quantiles', linewidth=0.2, cmap='YlOrRd', ax=ax, legend = True)
ax.set_axis_off()
plt.show()

# %% [markdown]
# #### The end of scripts

# %%
import glob
data_dir='../../GitHubData/DataScience_AI/data/GIS/標高傾斜度/' # e-stat 統計で見る日本　国税調査　小区分　境界データ　Shape ファイル　
slope_shp=sorted(glob.glob(data_dir+'/*/*.shp'))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas as gpd


fig, ax = plt.subplots(figsize = (16,16)) 
gdf = gpd.read_file(slope_shp[0])      #gdf file に変換した。
gdf.plot(ax=ax, facecolor=gdf['G04a_002'], edgecolor='black', linewidth=0.2)
ax.set_axis_off()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c72c27eab03f> in <module>
#       6 fig, ax = plt.subplots(figsize = (16,16))
#       7 gdf = gpd.read_file(slope_shp[0])      #gdf file に変換した。
# ----> 8 gdf.plot(ax=ax, facecolor=gdf['G04a_002'], edgecolor='black', linewidth=0.2)
#       9 ax.set_axis_off()
#      10 plt.show()
#
# ~/GDL/lib/python3.8/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     919         from there.
#     920         """
# --> 921         return plot_dataframe(self, *args, **kwargs)
#     922
#     923     plot.__doc__ = plot_dataframe.__doc__
#
# ~/GDL/lib/python3.8/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     613
#     614     if column is None:
# --> 615         return plot_series(
#     616             df.geometry,
#     617             cmap=cmap,
#
# ~/GDL/lib/python3.8/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     411
#     412         values_ = values[poly_idx] if cmap else None
# --> 413         _plot_polygon_collection(
#     414             ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     415         )
#
# ~/GDL/lib/python3.8/site-packages/geopandas/plotting.py in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     144     _expand_kwargs(kwargs, multiindex)
#     145
# --> 146     collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     147
#     148     if values is not None:
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, patches, match_original, **kwargs)
#    1812             kwargs['antialiaseds'] = [p.get_antialiased() for p in patches]
#    1813
# -> 1814         Collection.__init__(self, **kwargs)
#    1815
#    1816         self.set_paths(patches)
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     211
#     212         self._path_effects = None
# --> 213         self.update(kwargs)
#     214         self._paths = None
#     215
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/collections.py in set_facecolor(self, c)
#     778         """
#     779         self._original_facecolor = c
# --> 780         self._set_facecolor(c)
#     781
#     782     def get_facecolor(self):
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/collections.py in _set_facecolor(self, c)
#     762         except AttributeError:
#     763             pass
# --> 764         self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     765         self.stale = True
#     766
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     339         return np.zeros((0, 4), float)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#     343
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     339         return np.zeros((0, 4), float)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#     343
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     187         rgba = None
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#     191             _colors_full_map.cache[c, alpha] = rgba
#
# ~/GDL/lib/python3.8/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     258                     f"Value must be within 0-1 range")
#     259             return c, c, c, alpha if alpha is not None else 1.
# --> 260         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     261     # tuple color.
#     262     if not np.iterable(c):
#
# ValueError: Invalid RGBA argument: 'unknown'

# %%
gdf.head()
# Out:
#    G04a_001 G04a_002 G04a_003 G04a_004 G04a_005 G04a_006 G04a_007 G04a_008  \
# 0  50351600  unknown  unknown  unknown  unknown  unknown  unknown  unknown
# 1  50351601  unknown  unknown  unknown  unknown  unknown  unknown  unknown
# 2  50351602  unknown  unknown  unknown  unknown  unknown  unknown  unknown
# 3  50351603  unknown  unknown  unknown  unknown  unknown  unknown  unknown
# 4  50351604  unknown  unknown  unknown  unknown  unknown  unknown  unknown
#
#   G04a_009 G04a_010                                           geometry
# 0  unknown  unknown  POLYGON ((135.75000 33.41667, 135.75000 33.425...
# 1  unknown  unknown  POLYGON ((135.76250 33.41667, 135.76250 33.425...
# 2  unknown  unknown  POLYGON ((135.77500 33.41667, 135.77500 33.425...
# 3  unknown  unknown  POLYGON ((135.78750 33.41667, 135.78750 33.425...
# 4  unknown  unknown  POLYGON ((135.80000 33.41667, 135.80000 33.425...
